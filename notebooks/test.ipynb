# %%
# %load_ext autoreload
# %autoreload 2

# %%
from TaxiFareModel.data import get_data

df = get_data()
df
# Out:
#                                 key  ...  passenger_count
# 0     2012-04-30 22:35:00.000000171  ...                2
# 1     2013-11-25 14:48:00.000000179  ...                2
# 2       2014-09-20 20:46:13.0000002  ...                1
# 3       2014-09-19 23:05:00.0000001  ...                5
# 4      2012-07-17 17:17:00.00000080  ...                1
# ...                             ...  ...              ...
# 9995   2012-05-28 19:01:00.00000076  ...                5
# 9996  2011-05-02 21:18:00.000000138  ...                2
# 9997  2012-02-22 21:35:00.000000224  ...                3
# 9998    2010-05-25 23:36:04.0000004  ...                1
# 9999  2012-02-22 10:04:00.000000162  ...                1
#
# [10000 rows x 8 columns]

# %%
from TaxiFareModel.encoders import TimeFeaturesEncoder

test = TimeFeaturesEncoder('pickup_datetime')

df["dow","hour","month","year"]=test.fit_transform(df)[["dow","hour","month","year"]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/k9/1xvg6x991594dlshm5qcjr7w0000gn/T/ipykernel_47639/3710583812.py in <module>
#       3 test = TimeFeaturesEncoder('pickup_datetime')
#       4
# ----> 5 df["dow","hour","month","year"]=test.fit_transform(df)[["dow","hour","month","year"]]
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3038         else:
#    3039             # set column
# -> 3040             self._set_item(key, value)
#    3041
#    3042     def _setitem_slice(self, key: slice, value):
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3114         """
#    3115         self._ensure_valid_index(value)
# -> 3116         value = self._sanitize_column(key, value)
# ...

# %%
df
# Out:
#                                 key  ...  passenger_count
# 0     2012-04-30 22:35:00.000000171  ...                2
# 1     2013-11-25 14:48:00.000000179  ...                2
# 2       2014-09-20 20:46:13.0000002  ...                1
# 3       2014-09-19 23:05:00.0000001  ...                5
# 4      2012-07-17 17:17:00.00000080  ...                1
# ...                             ...  ...              ...
# 9995   2012-05-28 19:01:00.00000076  ...                5
# 9996  2011-05-02 21:18:00.000000138  ...                2
# 9997  2012-02-22 21:35:00.000000224  ...                3
# 9998    2010-05-25 23:36:04.0000004  ...                1
# 9999  2012-02-22 10:04:00.000000162  ...                1
#
# [10000 rows x 8 columns]
